# %% [markdown]
# # **ASSIGNMENT 1**

# %% [markdown]
# ## **SRAJAL AGARWAL**

# %%
# Importing the required libraries
import pandas as pd
import numpy as np

# %%
data = np.random.rand(4, 4) # Create NumPy array with random values
df = pd.DataFrame(data, columns=['feature_1', 'feature_2', 'feature_3', 'feature_4']) ## Create Pandas dataframe
print(df) #  Print the dataframe
# Out:
#    feature_1  feature_2  feature_3  feature_4
# 0   0.985851   0.420042   0.181034   0.625257
# 1   0.729049   0.252786   0.700907   0.723779
# 2   0.899923   0.040784   0.853567   0.232491
# 3   0.605388   0.392278   0.335463   0.344615

# %%
# Renaming the columns
df.columns = ['Random_value_1','Random_value_2','Random_value_3','Random_value_4']

# Print the values
print(df)
# Out:
#    Random_value_1  Random_value_2  Random_value_3  Random_value_4
# 0        0.985851        0.420042        0.181034        0.625257
# 1        0.729049        0.252786        0.700907        0.723779
# 2        0.899923        0.040784        0.853567        0.232491
# 3        0.605388        0.392278        0.335463        0.344615

# %%
# Using the .describe() method to find the descriptive statistics of the dataframe
df.describe()
# Out:
#        Random_value_1  Random_value_2  Random_value_3  Random_value_4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.805053        0.276472        0.517743        0.481536
# std          0.170617        0.173333        0.312477        0.231018
# min          0.605388        0.040784        0.181034        0.232491
# 25%          0.698134        0.199786        0.296856        0.316584
# 50%          0.814486        0.322532        0.518185        0.484936
# 75%          0.921405        0.399219        0.739072        0.649888
# max          0.985851        0.420042        0.853567        0.723779

# %%
# Checking individual values for null values
# -> True implies that it is a null value
# -> False implies that it is not a null value
print(f"Individually:\n{df.isnull()}")
# Out:
# Individually:
#    Random_value_1  Random_value_2  Random_value_3  Random_value_4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes # Get datatypes of columns
# Out:
# Random_value_1    float64
# Random_value_2    float64
# Random_value_3    float64
# Random_value_4    float64
# dtype: object

# %%
# Displaying the 'Random_value_2' & 'Random_value_3' column values using loc method
df.loc[:, ['Random_value_2','Random_value_3']]
# Out:
#    Random_value_2  Random_value_3
# 0        0.420042        0.181034
# 1        0.252786        0.700907
# 2        0.040784        0.853567
# 3        0.392278        0.335463

# %%
# Displaying the 'Random_value_2' & 'Random_value_3' column values using iloc method
df.iloc[:, 1:3]
# Out:
#    Random_value_2  Random_value_3
# 0        0.420042        0.181034
# 1        0.252786        0.700907
# 2        0.040784        0.853567
# 3        0.392278        0.335463
